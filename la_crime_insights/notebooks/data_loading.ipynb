# %%
import pandas as pd
pd.set_option('display.max_columns', None)
read_crime_data=pd.read_csv("../csv_files/raw_crime_data_2020_now.csv")
read_crime_data.head(8)

# %%
read_crime_data.shape

# %%
read_crime_data.describe()

# %%
read_crime_data.columns

# %%
null_data=read_crime_data.isnull().sum()
null_data

# %%
null_percentage=(null_data/len(read_crime_data))*100
null_percentage
